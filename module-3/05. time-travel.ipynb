# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-3/time-travel.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239536-lesson-5-time-travel)

# %% [markdown]
# # Time travel
#
# ## Review
#
# We discussed motivations for human-in-the-loop:
#
# (1) `Approval` - We can interrupt our agent, surface state to a user, and allow the user to accept an action
#
# (2) `Debugging` - We can rewind the graph to reproduce or avoid issues
#
# (3) `Editing` - You can modify the state
#
# We showed how breakpoints can stop the graph at specific nodes or allow the graph to dynamically interrupt itself.
#
# Then we showed how to proceed with human approval or directly edit the graph state with human feedback.
#
# ## Goals
#
# Now, let's show how LangGraph [supports debugging](https://langchain-ai.github.io/langgraph/how-tos/human_in_the_loop/time-travel/) by viewing, re-playing, and even forking from past states.
#
# We call this `time travel`.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph langchain_openai langgraph_sdk langgraph-prebuilt

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %% [markdown]
# Let's build our agent.

# %%
from langchain_openai import ChatOpenAI

def multiply(a: int, b: int) -> int:
    """Multiply a and b.

    Args:
        a: first int
        b: second int
    """
    return a * b

# This will be a tool
def add(a: int, b: int) -> int:
    """Adds a and b.

    Args:
        a: first int
        b: second int
    """
    return a + b

def divide(a: int, b: int) -> float:
    """Divide a by b.

    Args:
        a: first int
        b: second int
    """
    return a / b

tools = [add, multiply, divide]
llm = ChatOpenAI(model="gpt-4o")
llm_with_tools = llm.bind_tools(tools)

# %%
from IPython.display import Image, display

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import MessagesState
from langgraph.graph import START, END, StateGraph
from langgraph.prebuilt import tools_condition, ToolNode

from langchain_core.messages import AIMessage, HumanMessage, SystemMessage

# System message
sys_msg = SystemMessage(content="You are a helpful assistant tasked with performing arithmetic on a set of inputs.")

# Node
def assistant(state: MessagesState):
   return {"messages": [llm_with_tools.invoke([sys_msg] + state["messages"])]}

# Graph
builder = StateGraph(MessagesState)

# Define nodes: these do the work
builder.add_node("assistant", assistant)
builder.add_node("tools", ToolNode(tools))

# Define edges: these determine the control flow
builder.add_edge(START, "assistant")
builder.add_conditional_edges(
    "assistant",
    # If the latest message (result) from assistant is a tool call -> tools_condition routes to tools
    # If the latest message (result) from assistant is a not a tool call -> tools_condition routes to END
    tools_condition,
)
builder.add_edge("tools", "assistant")

memory = MemorySaver()
graph = builder.compile(checkpointer=MemorySaver())

# Show
display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %% [markdown]
# Let's run it, as before.

# %%
# Input
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}

# Thread
thread = {"configurable": {"thread_id": "1"}}

# Run the graph until the first interruption
for event in graph.stream(initial_input, thread, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 2 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_6DTgHUvmLGTKH3MPzFlU9ico)
#  Call ID: call_6DTgHUvmLGTKH3MPzFlU9ico
#   Args:
#     a: 2
#     b: 3
# ================================= Tool Message =================================
# Name: multiply
#
# 6
# ================================== Ai Message ==================================
#
# The result of multiplying 2 and 3 is 6.

# %% [markdown]
# ## Browsing History
#
# We can use `get_state` to look at the **current** state of our graph, given the `thread_id`!

# %%
graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='c79cc45e-e201-4ec8-9068-95d00de8a82e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6DTgHUvmLGTKH3MPzFlU9ico', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 131, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYg3AGzo1NoaNWt63gzfBByNw6Df', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--ada27f21-6bfd-4124-a13a-14873d55bab5-0', tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_6DTgHUvmLGTKH3MPzFlU9ico', 'type': 'tool_call'}], usage_metadata={'input_tokens': 131, 'output_tokens': 17, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='6', name='multiply', id='8bfd89b3-42f4-42b1-8f01-486ddb2a90e4', tool_call_id='call_6DTgHUvmLGTKH3MPzFlU9ico'), AIMessage(content='The result of multiplying 2 and 3 is 6.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 156, 'total_tokens': 170, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYg4QjSKbSxrEWvzPDzhg9rERcqm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--790970f3-7def-44cb-8377-b2437affb2b2-0', usage_metadata={'input_tokens': 156, 'output_tokens': 14, 'total_tokens': 170, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0a04fe-9906-6ed0-8003-ef6c88a78fa3'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2025-10-03T11:55:52.990262+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0a04fe-9256-658c-8002-e573827608bb'}}, tasks=(), interrupts=())

# %%
state = graph.get_state(thread)

# %%
for msg in state.values['messages']:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 2 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_6DTgHUvmLGTKH3MPzFlU9ico)
#  Call ID: call_6DTgHUvmLGTKH3MPzFlU9ico
#   Args:
#     a: 2
#     b: 3
# ================================= Tool Message =================================
# Name: multiply
#
# 6
# ================================== Ai Message ==================================
#
# The result of multiplying 2 and 3 is 6.

# %% [markdown]
# We can also browse the state history of our agent.
#
# `get_state_history` lets us get the state at all prior steps.

# %%
all_states = [s for s in graph.get_state_history(thread)]

# %%
len(all_states)
# Out:
# 5

# %% [markdown]
# The first element is the current state, just as we got from `get_state`.

# %%
for msg in all_states[2].values['messages']:
    print(msg.pretty_print())
# Out:
# ================================ Human Message =================================
#
# Multiply 2 and 3
# None
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_6DTgHUvmLGTKH3MPzFlU9ico)
#  Call ID: call_6DTgHUvmLGTKH3MPzFlU9ico
#   Args:
#     a: 2
#     b: 3
# None

# %% [markdown]
# Everything above we can visualize here:
#
# ![fig1.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038211b544898570be3_time-travel1.png)

# %% [markdown]
# ## Replaying
#
# We can re-run our agent from any of the prior steps.
#
# ![fig2.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038a0bd34b541c78fb8_time-travel2.png)

# %% [markdown]
# Let's look back at the step that recieved human input!

# %%
to_replay = all_states[2]

# %%
for msg in to_replay.values['messages']:
    msg.pretty_print()
# Out:
# ================================ Human Message =================================
#
# Multiply 2 and 3
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_6DTgHUvmLGTKH3MPzFlU9ico)
#  Call ID: call_6DTgHUvmLGTKH3MPzFlU9ico
#   Args:
#     a: 2
#     b: 3

# %% [markdown]
# Look at the state.

# %%
to_replay.values['messages']
# Out:
# [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='c79cc45e-e201-4ec8-9068-95d00de8a82e'),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6DTgHUvmLGTKH3MPzFlU9ico', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 131, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYg3AGzo1NoaNWt63gzfBByNw6Df', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--ada27f21-6bfd-4124-a13a-14873d55bab5-0', tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_6DTgHUvmLGTKH3MPzFlU9ico', 'type': 'tool_call'}], usage_metadata={'input_tokens': 131, 'output_tokens': 17, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %% [markdown]
# We can see the next node to call.

# %%
to_replay.next
# Out:
# ('tools',)

# %% [markdown]
# We also get the config, which tells us the `checkpoint_id` as well as the `thread_id`.

# %%
to_replay.config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0a04fe-924d-60f0-8001-218cefc0a1e1'}}

# %% [markdown]
# To replay from here, we simply pass the config back to the agent!
#
# The graph knows that this checkpoint has aleady been executed.
#
# It just re-plays from this checkpoint!

# %%
for event in graph.stream(None, to_replay.config, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================== Ai Message ==================================
# Tool Calls:
#   multiply (call_6DTgHUvmLGTKH3MPzFlU9ico)
#  Call ID: call_6DTgHUvmLGTKH3MPzFlU9ico
#   Args:
#     a: 2
#     b: 3
# ================================= Tool Message =================================
# Name: multiply
#
# 6
# ================================== Ai Message ==================================
#
# The product of 2 and 3 is 6.

# %% [markdown]
# Now, we can see our current state after the agent re-ran.

# %% [markdown]
# ## Forking
#
# What if we want to run from that same step, but with a different input.
#
# This is forking.
#
# ![fig3.jpg](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66dbb038f89f2d847ee5c336_time-travel3.png)

# %%
to_fork = all_states[1]
to_fork.values["messages"]
# Out:
# [HumanMessage(content='Multiply 2 and 3', additional_kwargs={}, response_metadata={}, id='c79cc45e-e201-4ec8-9068-95d00de8a82e'),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6DTgHUvmLGTKH3MPzFlU9ico', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 131, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYg3AGzo1NoaNWt63gzfBByNw6Df', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--ada27f21-6bfd-4124-a13a-14873d55bab5-0', tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_6DTgHUvmLGTKH3MPzFlU9ico', 'type': 'tool_call'}], usage_metadata={'input_tokens': 131, 'output_tokens': 17, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='6', name='multiply', id='8bfd89b3-42f4-42b1-8f01-486ddb2a90e4', tool_call_id='call_6DTgHUvmLGTKH3MPzFlU9ico')]

# %% [markdown]
# Again, we have the config.

# %%
to_fork.config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0a04fe-9256-658c-8002-e573827608bb'}}

# %% [markdown]
# Let's modify the state at this checkpoint.
#
# We can just run `update_state` with the `checkpoint_id` supplied.
#
# Remember how our reducer on `messages` works:
#
# * It will append, unless we supply a message ID.
# * We supply the message ID to overwrite the message, rather than appending to state!
#
# So, to overwrite the the message, we just supply the message ID, which we have `to_fork.values["messages"].id`.

# %%
fork_config = graph.update_state(
    to_fork.config,
    {"messages": [HumanMessage(content='Multiply 5 and 3', 
                               id=to_fork.values["messages"][0].id)]},
)

# %%
fork_config
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0a0503-b1c8-6cd6-8003-0fe9074ccc2c'}}

# %% [markdown]
# This creates a new, forked checkpoint.
#
# But, the metadata - e.g., where to go next - is perserved!
#
# We can see the current state of our agent has been updated with our fork.

# %%
#all_states = [s for s in graph.get_state_history(thread)]
all_states = [state for state in graph.get_state_history(thread) ]
all_states[0].values["messages"]
# Out:
# [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='c79cc45e-e201-4ec8-9068-95d00de8a82e'),
#  AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6DTgHUvmLGTKH3MPzFlU9ico', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 131, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYg3AGzo1NoaNWt63gzfBByNw6Df', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--ada27f21-6bfd-4124-a13a-14873d55bab5-0', tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_6DTgHUvmLGTKH3MPzFlU9ico', 'type': 'tool_call'}], usage_metadata={'input_tokens': 131, 'output_tokens': 17, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='6', name='multiply', id='8bfd89b3-42f4-42b1-8f01-486ddb2a90e4', tool_call_id='call_6DTgHUvmLGTKH3MPzFlU9ico')]

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='c79cc45e-e201-4ec8-9068-95d00de8a82e'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6DTgHUvmLGTKH3MPzFlU9ico', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 131, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYg3AGzo1NoaNWt63gzfBByNw6Df', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--ada27f21-6bfd-4124-a13a-14873d55bab5-0', tool_calls=[{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_6DTgHUvmLGTKH3MPzFlU9ico', 'type': 'tool_call'}], usage_metadata={'input_tokens': 131, 'output_tokens': 17, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='6', name='multiply', id='8bfd89b3-42f4-42b1-8f01-486ddb2a90e4', tool_call_id='call_6DTgHUvmLGTKH3MPzFlU9ico')]}, next=('assistant',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0a0503-b1c8-6cd6-8003-0fe9074ccc2c'}}, metadata={'source': 'update', 'step': 3, 'parents': {}}, created_at='2025-10-03T11:58:09.803979+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0a04fe-9256-658c-8002-e573827608bb'}}, tasks=(PregelTask(id='de6d1b12-0214-514e-4d88-ac24c8e767d8', name='assistant', path=('__pregel_pull', 'assistant'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %% [markdown]
# Now, when we stream, the graph knows this checkpoint has never been executed.
#
# So, the graph runs, rather than simply re-playing.

# %%
for event in graph.stream(None, fork_config, stream_mode="values"):
    event['messages'][-1].pretty_print()
# Out:
# ================================= Tool Message =================================
# Name: multiply
#
# 6
# ================================== Ai Message ==================================
#
# The result of multiplying 5 and 3 is 15.

# %% [markdown]
# Now, we can see the current state is the end of our agent run.

# %%
graph.get_state({'configurable': {'thread_id': '1'}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Multiply 5 and 3', additional_kwargs={}, response_metadata={}, id='ad15f237-f302-4df8-8bb1-50d52aade536'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_i75ruM1PowsuLyno2UcUXQwB', 'function': {'arguments': '{"a":5,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 131, 'total_tokens': 148, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYJ9NsXRLqcRLjghRKXrAfPo4Ix8', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run--ee246481-7c3e-456d-8e9a-d4ee7c673cb7-0', tool_calls=[{'name': 'multiply', 'args': {'a': 5, 'b': 3}, 'id': 'call_i75ruM1PowsuLyno2UcUXQwB', 'type': 'tool_call'}], usage_metadata={'input_tokens': 131, 'output_tokens': 17, 'total_tokens': 148, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='15', name='multiply', id='293f0b53-8675-441b-b566-9e83dd99808c', tool_call_id='call_i75ruM1PowsuLyno2UcUXQwB'), AIMessage(content='The result of multiplying 5 and 3 is 15.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 156, 'total_tokens': 170, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYJAlsQDvy0vhcNfstJcQhXGF5yk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--f7e88c18-bbcf-4c58-abfe-c7e871a42c4f-0', usage_metadata={'input_tokens': 156, 'output_tokens': 14, 'total_tokens': 170, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0a04c9-ae1d-6648-8005-cf6e3594d7bb'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2025-10-03T11:32:12.493545+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0a04c9-a756-6789-8004-fe1c64265684'}}, tasks=(), interrupts=())

# %% [markdown]
# ### Time travel with LangGraph API
#
# **⚠️ DISCLAIMER**
#
# Since the filming of these videos, we've updated Studio so that it can be run locally and opened in your browser. This is now the preferred way to run Studio (rather than using the Desktop App as shown in the video). See documentation [here](https://langchain-ai.github.io/langgraph/concepts/langgraph_studio/#local-development-server) on the local development server and [here](https://langchain-ai.github.io/langgraph/how-tos/local-studio/#run-the-development-server). To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the Studio UI: `https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024`.
#
# We connect to it via the SDK and show how the LangGraph API [supports time travel](https://langchain-ai.github.io/langgraph/cloud/how-tos/human_in_the_loop_time_travel/#initial-invocation).

# %%
if 'google.colab' in str(get_ipython()):
    raise Exception("Unfortunately LangGraph Studio is currently not supported on Google Colab")

# %%
from langgraph_sdk import get_client
client = get_client(url="http://127.0.0.1:2024")

# %% [markdown]
# #### Re-playing
#
# Let's run our agent streaming `updates` to the state of the graph after each node is called.

# %%
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}
thread = await client.threads.create()
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id = "agent",
    input=initial_input,
    stream_mode="updates",
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])
# Out:
# --------------------Assistant Node--------------------
# {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_sy3vSbrY6FtrbYI4cXEwcGpA', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 134, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYJgqr7kOOZ7nIoJI1aJsdma7Bzg', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--6ca18758-0f94-4b35-a5b0-c2e7c6e4ac7f-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_sy3vSbrY6FtrbYI4cXEwcGpA', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 17, 'total_tokens': 151, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}
# --------------------Tools Node--------------------
# {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': 'b28ff326-f500-41db-a67f-e2134d826bcb', 'tool_call_id': 'call_sy3vSbrY6FtrbYI4cXEwcGpA', 'artifact': None, 'status': 'success'}
# --------------------Assistant Node--------------------
# {'content': 'The result of multiplying 2 and 3 is 6.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 14, 'prompt_tokens': 159, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYJhUcpw15FknPzSq3RfZBMEKmT6', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--eb6716de-1ca2-4d69-83b8-f83020c4cb4c-0', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 159, 'output_tokens': 14, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}

# %% [markdown]
# Now, let's look at **replaying** from a specified checkpoint.
#
# We simply need to pass the `checkpoint_id`.

# %%
states = await client.threads.get_history(thread['thread_id'])
to_replay = states[-2]
to_replay
# Out:
# {'values': {'messages': [{'content': 'Multiply 2 and 3',
#     'additional_kwargs': {},
#     'response_metadata': {},
#     'type': 'human',
#     'name': None,
#     'id': 'a5aef484-8067-4e21-95b6-9b6a935ff427',
#     'example': False}]},
#  'next': ['assistant'],
#  'tasks': [{'id': 'e3c42d73-ffb0-0b2a-8e2a-cda5c7e376d3',
#    'name': 'assistant',
#    'path': ['__pregel_pull', 'assistant'],
#    'error': None,
#    'interrupts': [],
#    'checkpoint': None,
#    'state': None,
#    'result': {'messages': [{'content': '',
#       'additional_kwargs': {'tool_calls': [{'id': 'call_sy3vSbrY6FtrbYI4cXEwcGpA',
#          'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'},
#          'type': 'function'}],
#        'refusal': None},
#       'response_metadata': {'token_usage': {'completion_tokens': 17,
#         'prompt_tokens': 134,
#         'total_tokens': 151,
#         'completion_tokens_details': {'accepted_prediction_tokens': 0,
#          'audio_tokens': 0,
#          'reasoning_tokens': 0,
#          'rejected_prediction_tokens': 0},
#         'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#        'model_name': 'gpt-4o-2024-08-06',
#        'system_fingerprint': 'fp_f33640a400',
#        'id': 'chatcmpl-CMYJgqr7kOOZ7nIoJI1aJsdma7Bzg',
#        'service_tier': 'default',
#        'finish_reason': 'tool_calls',
#        'logprobs': None},
#       'type': 'ai',
#       'name': None,
#       'id': 'run--6ca18758-0f94-4b35-a5b0-c2e7c6e4ac7f-0',
#       'example': False,
#       'tool_calls': [{'name': 'multiply',
#         'args': {'a': 2, 'b': 3},
#         'id': 'call_sy3vSbrY6FtrbYI4cXEwcGpA',
#         'type': 'tool_call'}],
#       'invalid_tool_calls': [],
#       'usage_metadata': {'input_tokens': 134,
#        'output_tokens': 17,
#        'total_tokens': 151,
#        'input_token_details': {'audio': 0, 'cache_read': 0},
#        'output_token_details': {'audio': 0, 'reasoning': 0}}}]}}],
#  'metadata': {'langgraph_auth_user': None,
#   'langgraph_auth_user_id': '',
#   'langgraph_auth_permissions': [],
#   'langgraph_request_id': 'f03c4e1a-3115-485f-bc8a-ccd4cff486eb',
#   'graph_id': 'agent',
#   'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca',
#   'user_id': '',
#   'created_by': 'system',
#   'run_attempt': 1,
#   'langgraph_version': '0.6.8',
#   'langgraph_api_version': '0.4.28',
#   'langgraph_plan': 'developer',
#   'langgraph_host': 'self-hosted',
#   'langgraph_api_url': 'http://127.0.0.1:2024',
#   'run_id': '0199a9d8-7e92-70b3-a650-a2b638d38884',
#   'thread_id': '20981d4b-642b-4ec5-ac27-9dcb5ee433c4',
#   'source': 'loop',
#   'step': 0,
#   'parents': {}},
#  'created_at': '2025-10-03T11:32:42.483089+00:00',
#  'checkpoint': {'checkpoint_id': '1f0a04ca-cc1e-6099-8000-761858bda0d5',
#   'thread_id': '20981d4b-642b-4ec5-ac27-9dcb5ee433c4',
#   'checkpoint_ns': ''},
#  'parent_checkpoint': {'checkpoint_id': '1f0a04ca-cbda-6dcb-bfff-f451e789f193',
#   'thread_id': '20981d4b-642b-4ec5-ac27-9dcb5ee433c4',
#   'checkpoint_ns': ''},
#  'interrupts': [],
#  'checkpoint_id': '1f0a04ca-cc1e-6099-8000-761858bda0d5',
#  'parent_checkpoint_id': '1f0a04ca-cbda-6dcb-bfff-f451e789f193'}

# %% [markdown]
# Let's stream with `stream_mode="values"` to see the full state at every node as we replay.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="values",
    checkpoint_id=to_replay['checkpoint_id']
):      
    print(f"Receiving new event of type: {chunk.event}...")
    print(chunk.data)
    print("\n\n")
# Out:
# Receiving new event of type: metadata...
# {'run_id': '0199a9d9-e94a-76e1-8a5b-f05757445e20', 'attempt': 1}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'a5aef484-8067-4e21-95b6-9b6a935ff427', 'example': False}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'a5aef484-8067-4e21-95b6-9b6a935ff427', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_FZTq6YSYLMYKwzeuxta3JHxs', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 134, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYL9dVNd8aVQSIcj2ZR2aF5gXkJJ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--13d46e85-6eaa-45d1-9871-91908acfd0d3-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_FZTq6YSYLMYKwzeuxta3JHxs', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 17, 'total_tokens': 151, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'a5aef484-8067-4e21-95b6-9b6a935ff427', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_FZTq6YSYLMYKwzeuxta3JHxs', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 134, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYL9dVNd8aVQSIcj2ZR2aF5gXkJJ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--13d46e85-6eaa-45d1-9871-91908acfd0d3-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_FZTq6YSYLMYKwzeuxta3JHxs', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 17, 'total_tokens': 151, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '231d9e9c-12c7-4190-9b96-99f5b7227a61', 'tool_call_id': 'call_FZTq6YSYLMYKwzeuxta3JHxs', 'artifact': None, 'status': 'success'}]}
#
#
#
# Receiving new event of type: values...
# {'messages': [{'content': 'Multiply 2 and 3', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'human', 'name': None, 'id': 'a5aef484-8067-4e21-95b6-9b6a935ff427', 'example': False}, {'content': '', 'additional_kwargs': {'tool_calls': [{'id': 'call_FZTq6YSYLMYKwzeuxta3JHxs', 'function': {'arguments': '{"a":2,"b":3}', 'name': 'multiply'}, 'type': 'function'}], 'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 17, 'prompt_tokens': 134, 'total_tokens': 151, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYL9dVNd8aVQSIcj2ZR2aF5gXkJJ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--13d46e85-6eaa-45d1-9871-91908acfd0d3-0', 'example': False, 'tool_calls': [{'name': 'multiply', 'args': {'a': 2, 'b': 3}, 'id': 'call_FZTq6YSYLMYKwzeuxta3JHxs', 'type': 'tool_call'}], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 134, 'output_tokens': 17, 'total_tokens': 151, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}, {'content': '6', 'additional_kwargs': {}, 'response_metadata': {}, 'type': 'tool', 'name': 'multiply', 'id': '231d9e9c-12c7-4190-9b96-99f5b7227a61', 'tool_call_id': 'call_FZTq6YSYLMYKwzeuxta3JHxs', 'artifact': None, 'status': 'success'}, {'content': 'The result of multiplying 2 and 3 is 6.', 'additional_kwargs': {'refusal': None}, 'response_metadata': {'token_usage': {'completion_tokens': 14, 'prompt_tokens': 159, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f33640a400', 'id': 'chatcmpl-CMYLAWGyLhKj5YLCbXbg6e1Xf2nMp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, 'type': 'ai', 'name': None, 'id': 'run--d8bcf3a1-55e8-46df-b501-fd21bba8e6ca-0', 'example': False, 'tool_calls': [], 'invalid_tool_calls': [], 'usage_metadata': {'input_tokens': 159, 'output_tokens': 14, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}}]}

# %% [markdown]
# We can all view this as streaming only `updates` to state made by the nodes that we reply.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="updates",
    checkpoint_id=to_replay['checkpoint_id']
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])

# %% [markdown]
# #### Forking
#
# Now, let's look at forking.
#
# Let's get the same step as we worked with above, the human input.
#
# Let's create a new thread with our agent.

# %%
initial_input = {"messages": HumanMessage(content="Multiply 2 and 3")}
thread = await client.threads.create()
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=initial_input,
    stream_mode="updates",
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])

# %%
states = await client.threads.get_history(thread['thread_id'])
to_fork = states[-2]
to_fork['values']

# %%
to_fork['values']['messages'][0]['id']

# %%
to_fork['next']

# %%
to_fork['checkpoint_id']

# %% [markdown]
# Let's edit the state.
#
# Remember how our reducer on `messages` works:
#
# * It will append, unless we supply a message ID.
# * We supply the message ID to overwrite the message, rather than appending to state!

# %%
forked_input = {"messages": HumanMessage(content="Multiply 3 and 3",
                                         id=to_fork['values']['messages'][0]['id'])}

forked_config = await client.threads.update_state(
    thread["thread_id"],
    forked_input,
    checkpoint_id=to_fork['checkpoint_id']
)

# %%
forked_config

# %%
states = await client.threads.get_history(thread['thread_id'])
states[0]

# %% [markdown]
# To rerun, we pass in the `checkpoint_id`.

# %%
async for chunk in client.runs.stream(
    thread["thread_id"],
    assistant_id="agent",
    input=None,
    stream_mode="updates",
    checkpoint_id=forked_config['checkpoint_id']
):
    if chunk.data:
        assisant_node = chunk.data.get('assistant', {}).get('messages', [])
        tool_node = chunk.data.get('tools', {}).get('messages', [])
        if assisant_node:
            print("-" * 20+"Assistant Node"+"-" * 20)
            print(assisant_node[-1])
        elif tool_node:
            print("-" * 20+"Tools Node"+"-" * 20)
            print(tool_node[-1])

# %% [markdown]
# ### LangGraph Studio
#
# Let's look at forking in the Studio UI with our `agent`, which uses `module-1/studio/agent.py` set in `module-1/studio/langgraph.json`.
